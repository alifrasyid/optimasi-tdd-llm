# %%
# !pip install openpyxl requests
# !pip install evaluate
# !pip install sacrebleu
# !pip install codebleu[all]
# !pip install tree-sitter-python==0.21
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.11/dist-packages (3.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.14)
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.34.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.14)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.2 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.5
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.4 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2.0.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.4.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 7.1 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.2.0 sacrebleu-2.5.1
# Collecting codebleu[all]
#   Downloading codebleu-0.7.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting tree-sitter<0.23.0,>=0.22.0 (from codebleu[all])
#   Downloading tree_sitter-0.22.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools>=61.0.0 in /usr/local/lib/python3.11/dist-packages (from codebleu[all]) (75.2.0)
# Collecting tree-sitter-python~=0.21 (from codebleu[all])
#   Downloading tree_sitter_python-0.23.6-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting tree-sitter-go~=0.21 (from codebleu[all])
#   Downloading tree_sitter_go-0.23.4-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting tree-sitter-javascript~=0.21 (from codebleu[all])
#   Downloading tree_sitter_javascript-0.23.1-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.9 kB)
# Collecting tree-sitter-ruby~=0.21 (from codebleu[all])
#   Downloading tree_sitter_ruby-0.23.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting tree-sitter-php~=0.22 (from codebleu[all])
#   Downloading tree_sitter_php-0.23.11-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting tree-sitter-java~=0.21 (from codebleu[all])
#   Downloading tree_sitter_java-0.23.5-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting tree-sitter-c-sharp~=0.21 (from codebleu[all])
#   Downloading tree_sitter_c_sharp-0.23.1-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting tree-sitter-c~=0.21 (from codebleu[all])
#   Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting tree-sitter-cpp~=0.22 (from codebleu[all])
#   Downloading tree_sitter_cpp-0.23.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting tree-sitter-rust~=0.21 (from codebleu[all])
#   Downloading tree_sitter_rust-0.24.0-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.8 kB)
# Downloading tree_sitter-0.22.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (544 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.2/544.2 kB 16.5 MB/s eta 0:00:00
# Downloading tree_sitter_c-0.24.1-cp310-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 9.3 MB/s eta 0:00:00
# Downloading tree_sitter_c_sharp-0.23.1-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 kB 32.8 MB/s eta 0:00:00
# Downloading tree_sitter_cpp-0.23.4-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 28.0 MB/s eta 0:00:00
# Downloading tree_sitter_go-0.23.4-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.1 MB/s eta 0:00:00
# Downloading tree_sitter_java-0.23.5-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 7.8 MB/s eta 0:00:00
# Downloading tree_sitter_javascript-0.23.1-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 8.3 MB/s eta 0:00:00
# Downloading tree_sitter_php-0.23.11-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.5/251.5 kB 17.0 MB/s eta 0:00:00
# Downloading tree_sitter_python-0.23.6-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 kB 11.3 MB/s eta 0:00:00
# Downloading tree_sitter_ruby-0.23.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.4/214.4 kB 18.4 MB/s eta 0:00:00
# Downloading tree_sitter_rust-0.24.0-cp39-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.5/165.5 kB 14.8 MB/s eta 0:00:00
# Downloading codebleu-0.7.0-py3-none-any.whl (31 kB)
# Installing collected packages: tree-sitter-rust, tree-sitter-ruby, tree-sitter-python, tree-sitter-php, tree-sitter-javascript, tree-sitter-java, tree-sitter-go, tree-sitter-cpp, tree-sitter-c-sharp, tree-sitter-c, tree-sitter, codebleu
# Successfully installed codebleu-0.7.0 tree-sitter-0.22.3 tree-sitter-c-0.24.1 tree-sitter-c-sharp-0.23.1 tree-sitter-cpp-0.23.4 tree-sitter-go-0.23.4 tree-sitter-java-0.23.5 tree-sitter-javascript-0.23.1 tree-sitter-php-0.23.11 tree-sitter-python-0.23.6 tree-sitter-ruby-0.23.1 tree-sitter-rust-0.24.0
# Collecting tree-sitter-python==0.21
#   Downloading tree_sitter_python-0.21.0-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Downloading tree_sitter_python-0.21.0-cp38-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.6/130.6 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: tree-sitter-python
#   Attempting uninstall: tree-sitter-python
#     Found existing installation: tree-sitter-python 0.23.6
#     Uninstalling tree-sitter-python-0.23.6:
#       Successfully uninstalled tree-sitter-python-0.23.6
# Successfully installed tree-sitter-python-0.21.0

# %%
import json
import requests
import os
import time
import pandas as pd
import evaluate
import json
import re
import openpyxl
from openpyxl.utils import get_column_letter
from codebleu import calc_codebleu
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

# %%
os.environ["GROQ_API_KEY"] = ""

# %% [markdown]
# # **Scenario 1 (Requirement Pendek)**

# %%
# --- Konfigurasi ---
EXCEL_FILE = "scenario1.xlsx"
SHEET_NAME = "Lembar1"
REQUIREMENT_COLUMN = "Requirements"
RESOURCE_COLUMN = "Resources"
NAMETEST_COLUMN = "Name Test"
OUTPUT_COLUMN = "Generated Test"

GROQ_API_URL = "https://api.groq.com/openai/v1/chat/completions"
GROQ_MODEL = "llama3-70b-8192"
GROQ_API_KEY = os.environ.get("GROQ_API_KEY")

# --- Fungsi untuk Memanggil Groq API  ---
def call_groq_api(prompt, retries=3, delay=5):
    headers = {
        "Authorization": f"Bearer {GROQ_API_KEY}",
        "Content-Type": "application/json"
    }
    data = {
        "model": GROQ_MODEL,
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": 500,
        "temperature": 0.7
    }

    for attempt in range(retries):
        try:
            response = requests.post(GROQ_API_URL, headers=headers, json=data)
            if response.status_code == 429:
                print("Rate limit hit. Waiting before retry...")
                time.sleep(delay)
                continue
            response.raise_for_status()
            return response.json()["choices"][0]["message"]["content"]
        except requests.exceptions.RequestException as e:
            print(f"Error calling Groq API (attempt {attempt+1}): {e}")
            time.sleep(delay)
    return None

# --- Fungsi Utama ---
def generate_tests_from_excel(excel_file, sheet_name, requirement_column, output_column, resource_column, nametest_column):
    try:
        workbook = openpyxl.load_workbook(excel_file)
        sheet = workbook[sheet_name]
    except FileNotFoundError:
        print(f"Error: Excel file '{excel_file}' not found.")
        return
    except KeyError:
        print(f"Error: Sheet '{sheet_name}' not found in Excel file.")
        return

    header_row = 1
    requirement_col_index = None
    output_col_index = None
    resource_col_index = None
    nametest_col_index = None

    for col_num, cell in enumerate(sheet[header_row], start=1):
        if cell.value == requirement_column:
            requirement_col_index = col_num
        if cell.value == output_column:
            output_col_index = col_num
        if cell.value == resource_column:
            resource_col_index = col_num
        if cell.value == nametest_column:
            nametest_col_index = col_num

    if requirement_col_index is None or resource_col_index is None:
        print(f"Error: Required columns not found.")
        return

    for row_num in range(header_row + 1, sheet.max_row + 1):
        resource = sheet.cell(row=row_num, column=resource_col_index).value
        requirement = sheet.cell(row=row_num, column=requirement_col_index).value
        nametest = sheet.cell(row=row_num, column=nametest_col_index).value


        if requirement and resource and nametest:
            prompt = f"""You are a professional software tester. Based on the following API requirement, write a complete and structured unit test using Pytest.

Follow these rules:
1. Use clear and descriptive test function names.
2. Use the `token_client` fixture to send authenticated requests.
3. Assert the response status code and key data in the response.
4. Cover both success and failure scenarios if applicable.
5. Use the existing object fixture if provided (e.g., `organizer`, `user`, `bundle`, etc.).
6. Generate ONLY ONE `pytest` function that tests all possible cases in this requirement.
7. ABSOLUTELY DO NOT include any explanation, comments, or text outside the code.
8. Output MUST be ONLY the raw Python code enclosed in triple backticks.
9. The test function name MUST follow this template: {nametest}

Resource: {resource}

Requirement:
{requirement}

Example format:

```python
def test_<name>(...):
    ...
```"""
            print(f"\nProcessing requirement at row {row_num} for resource '{resource}'...")
            time.sleep(2.5)
            generated_test = call_groq_api(prompt)
            if generated_test:
                print(f"✅ Generated test for: {requirement}")
                if output_col_index:
                    code_block = generated_test.strip()
                    if "```python" in code_block:
                        code_block = code_block.split("```python")[1].split("```")[0].strip()
                    elif "```" in code_block:
                        code_block = code_block.split("```")[1].split("```")[0].strip()

                    sheet.cell(row=row_num, column=output_col_index).value = code_block

    if output_col_index:
        workbook.save(excel_file)
        print(f"\n✅ All generated tests saved to '{output_column}' column in '{excel_file}'.")

# --- Jalankan ---
if __name__ == "__main__":
    generate_tests_from_excel(EXCEL_FILE, SHEET_NAME, REQUIREMENT_COLUMN, OUTPUT_COLUMN, RESOURCE_COLUMN, NAMETEST_COLUMN)
# Out:
# Processing requirement at row 2 for resource 'Organizers'...
# ✅ Generated test for: Returns a list of all organizers the authenticated user/token has access to.
#
# Processing requirement at row 3 for resource 'Organizers'...
# ✅ Generated test for: Returns information on one organizer account, identified by its slug.
#
# Processing requirement at row 4 for resource 'Organizers'...
# ✅ Generated test for: Get current values of organizer settings. Permission required: “Can change organizer settings”
#
# Processing requirement at row 5 for resource 'Organizers'...
# ✅ Generated test for: Updates organizer settings. Note that PUT is not allowed here, only PATCH.
#
# Processing requirement at row 6 for resource 'Events'...
# ✅ Generated test for: Returns a list of all events within a given organizer the authenticated user/token has access to. Permission required: “Can change event settings”
#
# Processing requirement at row 7 for resource 'Events'...
# ✅ Generated test for: Returns information on one event, identified by its slug. Permission required: “Can change event settings”
#
# Processing requirement at row 8 for resource 'Events'...
# ✅ Generated test for: Creates a new event. Please note that events cannot be created as ‘live’ using this endpoint. Quotas and payment must be added to the event before sales can go live. Permission required: “Can create events”
#
# Processing requirement at row 9 for resource 'Events'...
# ✅ Generated test for: Updates an event. Permission required: “Can change event settings”
#
# Processing requirement at row 10 for resource 'Events'...
# ✅ Generated test for: Creates a new event with properties as set in the request body. The properties that are copied are: is_public, testmode, has_subevents, settings, plugin settings, items, variations, add-ons, quotas, categories, tax rules, questions. If the plugins, has_subevents, meta_data and/or is_public fields are present in the post body this will determine their value. Otherwise their value will be copied from the existing event. Please note that you can only copy from events under the same organizer this way. Use the clone_from parameter when creating a new event for this instead. Permission required: “Can create events”
#
# Processing requirement at row 11 for resource 'Events'...
# ✅ Generated test for: Delete an event. Note that events with orders cannot be deleted to ensure data integrity. Permission required: “Can change event settings”
#
# Processing requirement at row 12 for resource 'Events'...
# ✅ Generated test for: Get current values of event settings. Permission required: “Can change event settings” (Exception: with device auth, some settings can always be read.)
#
# Processing requirement at row 13 for resource 'Events'...
# ✅ Generated test for: Updates event settings. Note that PUT is not allowed here, only PATCH.
#
# Processing requirement at row 14 for resource 'Sub Events'...
# ✅ Generated test for: Returns a list of all sub-events of an event.
#
# Processing requirement at row 15 for resource 'Sub Events'...
# ✅ Generated test for: Creates a new subevent. Permission required: “Can create events”
#
# Processing requirement at row 16 for resource 'Sub Events'...
# ✅ Generated test for: Returns information on one sub-event, identified by its ID.
#
# Processing requirement at row 17 for resource 'Sub Events'...
# Error calling Groq API (attempt 1): 502 Server Error: Bad Gateway for url: https://api.groq.com/openai/v1/chat/completions
# ✅ Generated test for: Updates a sub-event, identified by its ID. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. Permission required: “Can change event settings”
#
# Processing requirement at row 18 for resource 'Sub Events'...
# ✅ Generated test for: Delete a sub-event. Note that events with orders cannot be deleted to ensure data integrity. Permission required: “Can change event settings”
#
# Processing requirement at row 19 for resource 'Sub Events'...
# ✅ Generated test for: Returns a list of all sub-events of any event series you have access to within an organizer account.
#
# Processing requirement at row 20 for resource 'Tax Rules'...
# ✅ Generated test for: Returns a list of all tax rules configured for an event.
#
# Processing requirement at row 21 for resource 'Tax Rules'...
# ✅ Generated test for: Returns information on one tax rule, identified by its ID.
#
# Processing requirement at row 22 for resource 'Tax Rules'...
# ✅ Generated test for: Create a new tax rule.
#
# Processing requirement at row 23 for resource 'Tax Rules'...
# ✅ Generated test for: Update a tax rule. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change.
#
# Processing requirement at row 24 for resource 'Tax Rules'...
# ✅ Generated test for: Delete a tax rule. Note that tax rules can only be deleted if they are not in use for any products, settings or orders. If you cannot delete a tax rule, this method will return a 403 status code and you can only discontinue using it everywhere else.
#
# Processing requirement at row 25 for resource 'Item Categories'...
# ✅ Generated test for: Returns a list of all categories within a given event.
#
# Processing requirement at row 26 for resource 'Item Categories'...
# ✅ Generated test for: Returns information on one category, identified by its ID.
#
# Processing requirement at row 27 for resource 'Item Categories'...
# ✅ Generated test for: Creates a new category
#
# Processing requirement at row 28 for resource 'Item Categories'...
# ✅ Generated test for: Update a category. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 29 for resource 'Item Categories'...
# ✅ Generated test for: Delete a category.
#
# Processing requirement at row 30 for resource 'Items'...
# ✅ Generated test for: Returns a list of all items within a given event.
#
# Processing requirement at row 31 for resource 'Items'...
# ✅ Generated test for: Returns information on one item, identified by its ID.
#
# Processing requirement at row 32 for resource 'Items'...
# ✅ Generated test for: Creates a new item
#
# Processing requirement at row 33 for resource 'Items'...
# ✅ Generated test for: Update an item. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the has_variations, variations and the addon field. If you need to update/delete variations or add-ons please use the nested dedicated endpoints.
#
# Processing requirement at row 34 for resource 'Items'...
# ✅ Generated test for: Delete an item.
#
# Processing requirement at row 35 for resource 'Item Variations'...
# ✅ Generated test for: Returns a list of all variations for a given item.
#
# Processing requirement at row 36 for resource 'Item Variations'...
# ✅ Generated test for: Returns information on one variation, identified by its ID.
#
# Processing requirement at row 37 for resource 'Item Variations'...
# ✅ Generated test for: Creates a new variation
#
# Processing requirement at row 38 for resource 'Item Variations'...
# ✅ Generated test for: Update a variation. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id and the price field.
#
# Processing requirement at row 39 for resource 'Item Variations'...
# ✅ Generated test for: Delete a variation.
#
# Processing requirement at row 40 for resource 'Item Bundles'...
# ✅ Generated test for: Returns a list of all bundles for a given item.
#
# Processing requirement at row 41 for resource 'Item Bundles'...
# ✅ Generated test for: Returns information on one bundle configuration, identified by its ID.
#
# Processing requirement at row 42 for resource 'Item Bundles'...
# ✅ Generated test for: Creates a new bundle configuration
#
# Processing requirement at row 43 for resource 'Item Bundles'...
# ✅ Generated test for: Update a bundle configuration. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 44 for resource 'Item Bundles'...
# ✅ Generated test for: Delete a bundle configuration.
#
# Processing requirement at row 45 for resource 'Item Add-Ons'...
# ✅ Generated test for: Returns a list of all add-ons for a given item.
#
# Processing requirement at row 46 for resource 'Item Add-Ons'...
# ✅ Generated test for: Returns information on one add-on, identified by its ID.
#
# Processing requirement at row 47 for resource 'Item Add-Ons'...
# ✅ Generated test for: Creates a new add-on
#
# Processing requirement at row 48 for resource 'Item Add-Ons'...
# ✅ Generated test for: Update an add-on. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 49 for resource 'Item Add-Ons'...
# ✅ Generated test for: Delete an add-on.
#
# Processing requirement at row 50 for resource 'Item Meta Properties'...
# ✅ Generated test for: Returns a list of all Item Meta Properties within a given event.
#
# Processing requirement at row 51 for resource 'Item Meta Properties'...
# ✅ Generated test for: Returns information on one property, identified by its id.
#
# Processing requirement at row 52 for resource 'Item Meta Properties'...
# ✅ Generated test for: Creates a new item meta property
#
# Processing requirement at row 53 for resource 'Item Meta Properties'...
# ✅ Generated test for: Update an item meta property. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 54 for resource 'Item Meta Properties'...
# ✅ Generated test for: Delete an item meta property.
#
# Processing requirement at row 55 for resource 'Teams'...
# ✅ Generated test for: Returns a list of all teams within a given organizer.
#
# Processing requirement at row 56 for resource 'Teams'...
# ✅ Generated test for: Returns information on one team, identified by its ID.
#
# Processing requirement at row 57 for resource 'Teams'...
# ✅ Generated test for: Creates a new team
#
# Processing requirement at row 58 for resource 'Teams'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a team. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change.
#
# Processing requirement at row 59 for resource 'Teams'...
# ✅ Generated test for: Deletes a team.
#
# Processing requirement at row 60 for resource 'Teams'...
# ✅ Generated test for: Returns a list of all members of a team.
#
# Processing requirement at row 61 for resource 'Teams'...
# ✅ Generated test for: Returns information on one team member, identified by their ID.
#
# Processing requirement at row 62 for resource 'Teams'...
# ✅ Generated test for: Removes a member from the team.
#
# Processing requirement at row 63 for resource 'Teams'...
# ✅ Generated test for: Returns a list of all invitations to a team.
#
# Processing requirement at row 64 for resource 'Teams'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns information on one invite, identified by its ID.
#
# Processing requirement at row 65 for resource 'Teams'...
# ✅ Generated test for: Invites someone into the team. Note that if the user already has a pretix account, you will receive a response without an id and instead of an invite being created, the user will be directly added to the team.
#
# Processing requirement at row 66 for resource 'Teams'...
# ✅ Generated test for: Revokes an invite.
#
# Processing requirement at row 67 for resource 'Teams'...
# ✅ Generated test for: Returns a list of all API tokens of a team.
#
# Processing requirement at row 68 for resource 'Teams'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns information on one token, identified by its ID.
#
# Processing requirement at row 69 for resource 'Teams'...
# ✅ Generated test for: Creates a new token.
#
# Processing requirement at row 70 for resource 'Teams'...
# ✅ Generated test for: Disables a token.
#
# Processing requirement at row 71 for resource 'Customers'...
# ✅ Generated test for: Returns a list of all customers registered with a given organizer.
#
# Processing requirement at row 72 for resource 'Customers'...
# ✅ Generated test for: Returns information on one customer, identified by its identifier.
#
# Processing requirement at row 73 for resource 'Customers'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Creates a new customer. In addition to the fields defined on the resource, you can pass the field send_email to control whether the system should send an account activation email with a password reset link (defaults to false).
#
# Processing requirement at row 74 for resource 'Customers'...
# ✅ Generated test for: Update a customer. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the identifier, last_login, date_joined, name (which is auto-generated from name_parts), and last_modified fields.
#
# Processing requirement at row 75 for resource 'Customers'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Anonymize a customer. Deletes personal data and disconnects from existing orders.
#
# Processing requirement at row 76 for resource 'Discounts'...
# ✅ Generated test for: Returns a list of all discounts within a given event.
#
# Processing requirement at row 77 for resource 'Discounts'...
# ✅ Generated test for: Returns information on one discount, identified by its ID.
#
# Processing requirement at row 78 for resource 'Discounts'...
# ✅ Generated test for: Creates a new discount
#
# Processing requirement at row 79 for resource 'Discounts'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a discount. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 80 for resource 'Discounts'...
# ✅ Generated test for: Delete a discount.
#
# Processing requirement at row 81 for resource 'Devices'...
# ✅ Generated test for: Returns a list of all devices within a given organizer.
#
# Processing requirement at row 82 for resource 'Devices'...
# ✅ Generated test for: Returns information on one device, identified by its ID.
#
# Processing requirement at row 83 for resource 'Devices'...
# ✅ Generated test for: Creates a new device
#
# Processing requirement at row 84 for resource 'Devices'...
# ✅ Generated test for: Update a device.
#
# Processing requirement at row 85 for resource 'Memberships'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns a list of all memberships within a given organizer.
#
# Processing requirement at row 86 for resource 'Memberships'...
# ✅ Generated test for: Returns information on one membership, identified by its ID.
#
# Processing requirement at row 87 for resource 'Memberships'...
# ✅ Generated test for: Creates a new membership
#
# Processing requirement at row 88 for resource 'Memberships'...
# ✅ Generated test for: Update a membership. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id, customer, and testmode fields.
#
# Processing requirement at row 89 for resource 'Membership Types'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns a list of all membership types within a given organizer.
#
# Processing requirement at row 90 for resource 'Membership Types'...
# ✅ Generated test for: Returns information on one membership type, identified by its ID.
#
# Processing requirement at row 91 for resource 'Membership Types'...
# ✅ Generated test for: Creates a new membership type
#
# Processing requirement at row 92 for resource 'Membership Types'...
# ✅ Generated test for: Update a membership type. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 93 for resource 'Membership Types'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Delete a membership type. You can not delete types which have already been used.
#
# Processing requirement at row 94 for resource 'Sales Channels'...
# ✅ Generated test for: Returns a list of all sales channels within a given organizer.
#
# Processing requirement at row 95 for resource 'Sales Channels'...
# ✅ Generated test for: Returns information on one sales channel, identified by its identifier.
#
# Processing requirement at row 96 for resource 'Sales Channels'...
# ✅ Generated test for: Creates a sales channel
#
# Processing requirement at row 97 for resource 'Sales Channels'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a sales channel. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the identifier and type fields.
#
# Processing requirement at row 98 for resource 'Sales Channels'...
# ✅ Generated test for: Delete a sales channel. You can not delete sales channels which have already been used or which are integral parts of the system.
#
# Processing requirement at row 99 for resource 'Seating Plans'...
# ✅ Generated test for: Returns a list of all seating plans within a given organizer.
#
# Processing requirement at row 100 for resource 'Seating Plans'...
# ✅ Generated test for: Returns information on one plan, identified by its ID.
#
# Processing requirement at row 101 for resource 'Seating Plans'...
# ✅ Generated test for: Creates a new seating plan
#
# Processing requirement at row 102 for resource 'Seating Plans'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a plan. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field. You can not change a plan while it is in use for any events.
#
# Processing requirement at row 103 for resource 'Seating Plans'...
# ✅ Generated test for: Delete a plan. You can not delete plans which are currently in use by any events.
#
# Processing requirement at row 104 for resource 'Gift Cards'...
# ✅ Generated test for: Returns a list of all gift cards issued by a given organizer.
#
# Processing requirement at row 105 for resource 'Gift Cards'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns information on one gift card, identified by its ID.
#
# Processing requirement at row 106 for resource 'Gift Cards'...
# ✅ Generated test for: Creates a new gift card
#
# Processing requirement at row 107 for resource 'Gift Cards'...
# ✅ Generated test for: Update a gift card. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id, secret, testmode, and currency fields. Be careful when modifying the value field to avoid race conditions. We recommend to use the transact method described below.
#
# Processing requirement at row 108 for resource 'Gift Cards'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Atomically change the value of a gift card. A positive amount will increase the value of the gift card, a negative amount will decrease it.
#
# Processing requirement at row 109 for resource 'Gift Cards'...
# ✅ Generated test for: List all transactions of a gift card.
#
# Processing requirement at row 110 for resource 'Scheduled email rules'...
# ✅ Generated test for: Returns a list of all rules configured for an event.
#
# Processing requirement at row 111 for resource 'Scheduled email rules'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns information on one rule, identified by its ID.
#
# Processing requirement at row 112 for resource 'Scheduled email rules'...
# ✅ Generated test for: Create a new rule.
#
# Processing requirement at row 113 for resource 'Scheduled email rules'...
# ✅ Generated test for: Update a rule. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change.
#
# Processing requirement at row 114 for resource 'Scheduled email rules'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Delete a rule.
#
# Processing requirement at row 115 for resource 'Webhooks'...
# ✅ Generated test for: Returns a list of all webhooks within a given organizer.
#
# Processing requirement at row 116 for resource 'Webhooks'...
# ✅ Generated test for: Returns information on one webhook, identified by its ID.
#
# Processing requirement at row 117 for resource 'Webhooks'...
# ✅ Generated test for: Creates a new webhook
#
# Processing requirement at row 118 for resource 'Webhooks'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a webhook. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 119 for resource 'Webhooks'...
# ✅ Generated test for: Delete a webhook. Currently, this will not delete but just disable the webhook.
#
# Processing requirement at row 120 for resource 'Reusable Media'...
# ✅ Generated test for: Returns a list of all media issued by a given organizer.
#
# Processing requirement at row 121 for resource 'Reusable Media'...
# ✅ Generated test for: Returns information on one medium, identified by its ID.
#
# Processing requirement at row 122 for resource 'Reusable Media'...
# ✅ Generated test for: Creates a new reusable medium.
#
# Processing requirement at row 123 for resource 'Reusable Media'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a reusable medium. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id, identifier and type fields.
#
# Processing requirement at row 124 for resource 'Reusable Media'...
# ✅ Generated test for: Look up a new reusable medium by its identifier. In some cases, this might lead to the automatic creation of a new medium behind the scenes. This endpoint, and this endpoint only, might return media from a different organizer if there is a cross-acceptance agreement. In this case, only linked gift cards will be returned, no order position or customer records,
#
# Processing requirement at row 125 for resource 'Vouchers'...
# ✅ Generated test for: Returns a list of all vouchers within a given event.
#
# Processing requirement at row 126 for resource 'Vouchers'...
# ✅ Generated test for: Returns information on one voucher, identified by its internal ID.
#
# Processing requirement at row 127 for resource 'Vouchers'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Create a new voucher.
#
# Processing requirement at row 128 for resource 'Vouchers'...
# ✅ Generated test for: Update a voucher. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id and redeemed fields.
#
# Processing requirement at row 129 for resource 'Vouchers'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Delete a voucher. Note that you cannot delete a voucher if it already has been redeemed.
#
# Processing requirement at row 130 for resource 'Vouchers'...
# ✅ Generated test for: Creates multiple new vouchers atomically.
#
# Processing requirement at row 131 for resource 'Waiting list entries'...
# ✅ Generated test for: Returns a list of all waiting list entries within a given event.
#
# Processing requirement at row 132 for resource 'Waiting list entries'...
# ✅ Generated test for: Returns information on one waiting list entry, identified by its internal ID.
#
# Processing requirement at row 133 for resource 'Waiting list entries'...
# ✅ Generated test for: Create a new entry.
#
# Processing requirement at row 134 for resource 'Waiting list entries'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update an entry. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id, voucher and created fields. You can only change an entry as long as no voucher is set.
#
# Processing requirement at row 135 for resource 'Waiting list entries'...
# ✅ Generated test for: Manually sends a voucher to someone on the waiting list
#
# Processing requirement at row 136 for resource 'Waiting list entries'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Delete an entry. Note that you cannot delete an entry once it is assigned a voucher.
#
# Processing requirement at row 137 for resource 'Check-in lists'...
# ✅ Generated test for: Returns a list of all check-in lists within a given event.
#
# Processing requirement at row 138 for resource 'Check-in lists'...
# ✅ Generated test for: Returns information on one check-in list, identified by its ID.
#
# Processing requirement at row 139 for resource 'Check-in lists'...
# ✅ Generated test for: Creates a new check-in list.
#
# Processing requirement at row 140 for resource 'Check-in lists'...
# ✅ Generated test for: Update a check-in list. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field and the checkin_count and position_count fields.
#
# Processing requirement at row 141 for resource 'Check-in lists'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns detailed status information on a check-in list, identified by its ID.
#
# Processing requirement at row 142 for resource 'Check-in lists'...
# ✅ Generated test for: Tries to redeem an order position, identified by its internal ID, i.e. checks the attendee in. This endpoint accepts a number of optional requests in the body. Tip: Instead of an ID, you can also use the secret field as the lookup parameter. In this case, you should always set untrusted_input=true as a query parameter to avoid security issues.
#
# Processing requirement at row 143 for resource 'Check-in lists'...
# ✅ Generated test for: Stores a failed check-in. Only necessary for statistical purposes if you perform scan validation offline.
#
# Processing requirement at row 144 for resource 'Orders'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns a list of all orders within a given event.
#
# Processing requirement at row 145 for resource 'Orders'...
# ✅ Generated test for: Returns a list of all orders within all events of a given organizer (with sufficient access permissions). Supported query parameters and output format of this endpoint are identical to the list endpoint within an event, with the exception that the pdf_data parameter is not supported here.
#
# Processing requirement at row 146 for resource 'Orders'...
# ✅ Generated test for: Returns information on one order, identified by its order code.
#
# Processing requirement at row 147 for resource 'Orders'...
# ✅ Generated test for: Creates a new order.
#
# Processing requirement at row 148 for resource 'Orders'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Reactivates a canceled order. This will set the order to pending or paid state. Only possible if all products are still available.
#
# Processing requirement at row 149 for resource 'Orders'...
# ✅ Generated test for: Approve an order that is pending approval.
#
# Processing requirement at row 150 for resource 'Orders'...
# ✅ Generated test for: Marks an order that is pending approval as denied.
#
# Processing requirement at row 151 for resource 'Orders'...
# ✅ Generated test for: Deletes an order. Works only if the order has testmode set to true.
#
# Processing requirement at row 152 for resource 'Orders'...
# ✅ Generated test for: Creates an invoice for an order which currently does not have an invoice. Returns the invoice object.
#
# Processing requirement at row 153 for resource 'Orders'...
# ✅ Generated test for: Triggers generation of new secret and web_secret attributes for both the order and all order positions.
#
# Processing requirement at row 154 for resource 'Orders'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Triggers generation of a new secret and web_secret attribute for a single order position.
#
# Processing requirement at row 155 for resource 'Orders'...
# ✅ Generated test for: Sends an email to the buyer with the link to the order page.
#
# Processing requirement at row 156 for resource 'Orders'...
# ✅ Generated test for: Returns a list of all order positions within a given event.
#
# Processing requirement at row 157 for resource 'Orders'...
# ✅ Generated test for: Returns information on one order position, identified by its internal ID.
#
# Processing requirement at row 158 for resource 'Orders'...
# ✅ Generated test for: Cancels an order position, identified by its internal ID.
#
# Processing requirement at row 159 for resource 'Orders'...
# ✅ Generated test for: Creates a print log, stating that this ticket has been printed.
#
# Processing requirement at row 160 for resource 'Orders'...
# ✅ Generated test for: Returns a list of all payments for an order.
#
# Processing requirement at row 161 for resource 'Orders'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns information on one payment, identified by its order-local ID.
#
# Processing requirement at row 162 for resource 'Orders'...
# ✅ Generated test for: Marks a payment as confirmed. Only allowed in states pending and created.
#
# Processing requirement at row 163 for resource 'Orders'...
# ✅ Generated test for: Marks a payment as canceled. Only allowed in states pending and created.
#
# Processing requirement at row 164 for resource 'Orders'...
# ✅ Generated test for: Create and execute a manual refund. Only available in confirmed state. Returns a refund resource, not a payment resource!
#
# Processing requirement at row 165 for resource 'Orders'...
# ✅ Generated test for: Creates a new payment.
#
# Processing requirement at row 166 for resource 'Orders'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns a list of all refunds for an order.
#
# Processing requirement at row 167 for resource 'Orders'...
# ✅ Generated test for: Returns information on one refund, identified by its order-local ID.
#
# Processing requirement at row 168 for resource 'Orders'...
# ✅ Generated test for: Marks a refund as completed. Only allowed in states transit and created.
#
# Processing requirement at row 169 for resource 'Orders'...
# ✅ Generated test for: Marks a refund as canceled. Only allowed in states transit, external, and created.
#
# Processing requirement at row 170 for resource 'Orders'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Creates a refund manually.
#
# Processing requirement at row 171 for resource 'Orders'...
# ✅ Generated test for: Returns a list of all revoked secrets within a given event.
#
# Processing requirement at row 172 for resource 'Orders'...
# ✅ Generated test for: Returns a list of all blocked or historically blocked secrets within a given event.
#
# Processing requirement at row 173 for resource 'Invoices'...
# ✅ Generated test for: Returns a list of all invoices within a given event.
#
# Processing requirement at row 174 for resource 'Invoices'...
# ✅ Generated test for: Returns a list of all invoices within all events of a given organizer (with sufficient access permissions). Supported query parameters and output format of this endpoint are identical to the list endpoint within an event.
#
# Processing requirement at row 175 for resource 'Invoices'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Returns information on one invoice, identified by its invoice number.
#
# Processing requirement at row 176 for resource 'Invoices'...
# ✅ Generated test for: Cancels the invoice and creates a new one.
#
# Processing requirement at row 177 for resource 'Invoices'...
# ✅ Generated test for: Re-generates the invoice from order data.
#
# Processing requirement at row 178 for resource 'Questions'...
# ✅ Generated test for: Returns a list of all questions within a given event.
#
# Processing requirement at row 179 for resource 'Questions'...
# ✅ Generated test for: Returns information on one question, identified by its ID.
#
# Processing requirement at row 180 for resource 'Questions'...
# ✅ Generated test for: Creates a new question
#
# Processing requirement at row 181 for resource 'Questions'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a question. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the options field. If you need to update/delete options please use the nested dedicated endpoints.
#
# Processing requirement at row 182 for resource 'Questions'...
# ✅ Generated test for: Delete a question.
#
# Processing requirement at row 183 for resource 'Question Options'...
# ✅ Generated test for: Returns a list of all options for a given question.
#
# Processing requirement at row 184 for resource 'Question Options'...
# ✅ Generated test for: Returns information on one option, identified by its ID.
#
# Processing requirement at row 185 for resource 'Question Options'...
# ✅ Generated test for: Creates a new option
#
# Processing requirement at row 186 for resource 'Question Options'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update an option. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 187 for resource 'Question Options'...
# ✅ Generated test for: Delete an option.
#
# Processing requirement at row 188 for resource 'Quotas'...
# ✅ Generated test for: Returns a list of all quotas within a given event.
#
# Processing requirement at row 189 for resource 'Quotas'...
# ✅ Generated test for: Returns information on one quota, identified by its ID.
#
# Processing requirement at row 190 for resource 'Quotas'...
# ✅ Generated test for: Creates a new quota
#
# Processing requirement at row 191 for resource 'Quotas'...
# Rate limit hit. Waiting before retry...
# ✅ Generated test for: Update a quota. You can also use PUT instead of PATCH. With PUT, you have to provide all fields of the resource, other fields will be reset to default. With PATCH, you only need to provide the fields that you want to change. You can change all fields of the resource except the id field.
#
# Processing requirement at row 192 for resource 'Quotas'...
# ✅ Generated test for: Delete a quota. Note that if you delete a quota the items the quota acts on might no longer be available for sale.
#
# Processing requirement at row 193 for resource 'Quotas'...
# ✅ Generated test for: Returns availability information on one quota, identified by its ID.
#
# ✅ All generated tests saved to 'Generated Test' column in 'scenario1.xlsx'.

# %% [markdown]
# # **Scenario 2 (Requirement Panjang)**

# %%
# --- Konfigurasi ---
JSON_FILE = "scenario2.json"
GROQ_API_URL = "https://api.groq.com/openai/v1/chat/completions"
GROQ_MODEL = "llama3-70b-8192"
GROQ_API_KEY = os.environ.get("GROQ_API_KEY")
EXCEL_PATH = "/content/scenario2.xlsx"

# --- Fungsi untuk Memanggil Groq API ---
def call_groq_api(prompt, retries=3, delay=5):
    headers = {
        "Authorization": f"Bearer {GROQ_API_KEY}",
        "Content-Type": "application/json"
    }
    data = {
        "model": GROQ_MODEL,
        "messages": [{"role": "user", "content": prompt}],
        "max_tokens": 500,
        "temperature": 0.7
    }

    for attempt in range(retries):
        try:
            response = requests.post(GROQ_API_URL, headers=headers, json=data)
            if response.status_code == 429:
                print("Rate limit hit. Waiting before retry...")
                time.sleep(delay)
                continue
            response.raise_for_status()
            return response.json()["choices"][0]["message"]["content"]
        except requests.exceptions.RequestException as e:
            print(f"Error calling Groq API (attempt {attempt+1}): {e}")
            time.sleep(delay)
    return None

# --- Fungsi Utama ---
def generate_tests_from_json_to_excel(json_file, excel_path):
    try:
        with open(json_file, "r", encoding="utf-8") as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"❌ File '{json_file}' tidak ditemukan.")
        return

    wb = openpyxl.load_workbook(excel_path)
    ws = wb.active

    # Cari kolom "Generated Test"
    header_row = ws[1]
    headers = {cell.value.strip(): idx + 1 for idx, cell in enumerate(header_row)}
    if "Generated Test" not in headers:
        print("❌ Kolom 'Generated Test' tidak ditemukan.")
        return
    generated_test_col = headers["Generated Test"]

    row_index = 2  # mulai dari baris ke-2 (asumsikan baris pertama adalah header)
    for section_name, section_data in data.items():
        description = section_data.get("description", "")
        endpoints = section_data.get("endpoints", {})

        for endpoint_path, endpoint_details in endpoints.items():
            method = endpoint_path.split()[0]
            url = endpoint_path.split()[1]
            name_test = endpoint_details.get("name_test", "def test_example(...):")

            requirement = f"""You are a professional software tester. Based on the following API requirement, write a complete and structured unit test using Pytest.

Follow these rules:
1. Use clear and descriptive test function names.
2. Use the `token_client` fixture to send authenticated requests.
3. Assert the response status code and key data in the response.
4. Cover both success and failure scenarios if applicable.
5. Use the existing object fixture if provided (e.g., `organizer`, `user`, `bundle`, etc.).
6. Generate ONLY ONE `pytest` function that tests all possible cases in this requirement.
7. ABSOLUTELY DO NOT include any explanation, comments, or text outside the code.
8. Output MUST be ONLY the raw Python code enclosed in triple backticks.
9. The test function name MUST follow this template: {name_test}

Entity: {section_name}
Description: {description}

Endpoint: {endpoint_path}
Details: {json.dumps(endpoint_details, indent=2)}

Example format:

```python
def test_<name>(...):
    ...
```"""

            print(f"\n🔄 Processing: {endpoint_path}")
            time.sleep(2.5)
            result = call_groq_api(requirement)

            if result:
                code_block = result.strip()
                if "```python" in code_block:
                    code_block = code_block.split("```python")[1].split("```")[0].strip()
                elif "```" in code_block:
                    code_block = code_block.split("```")[1].split("```")[0].strip()

                ws.cell(row=row_index, column=generated_test_col).value = code_block
                print(f"✅ Generated test inserted at row {row_index}")

            row_index += 1

    wb.save(excel_path)
    print(f"\n✅ All generated tests have been saved in '{excel_path}'.")


# --- Jalankan ---
if __name__ == "__main__":
    generate_tests_from_json_to_excel(JSON_FILE, EXCEL_PATH)
# Out:
# 🔄 Processing: GET /api/v1/organizers/
# ✅ Generated test inserted at row 2
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/
# ✅ Generated test inserted at row 3
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/settings/
# ✅ Generated test inserted at row 4
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/settings/
# ✅ Generated test inserted at row 5
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/
# ✅ Generated test inserted at row 6
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/
# ✅ Generated test inserted at row 7
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/
# ✅ Generated test inserted at row 8
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/clone/
# ✅ Generated test inserted at row 9
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/
# ✅ Generated test inserted at row 10
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/
# ✅ Generated test inserted at row 11
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/settings/
# ✅ Generated test inserted at row 12
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/settings/
# ✅ Generated test inserted at row 13
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/subevents/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 14
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/subevents/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 15
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/subevents/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 16
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/subevents/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 17
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/subevents/(id)/
# ✅ Generated test inserted at row 18
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/subevents/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 19
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/taxrules/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 20
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/taxrules/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 21
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/taxrules/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 22
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/taxrules/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 23
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/taxrules/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 24
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/categories/
# ✅ Generated test inserted at row 25
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/categories/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 26
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/categories/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 27
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/categories/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 28
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/category/(id)/
# ✅ Generated test inserted at row 29
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 30
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 31
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/items/
# ✅ Generated test inserted at row 32
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/items/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 33
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/items/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 34
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/(item)/variations/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 35
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/(item)/variations/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 36
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/items/(item)/variations/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 37
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/items/(item)/variations/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 38
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/items/(id)/variations/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 39
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/(item)/bundles/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 40
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/(item)/bundles/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 41
#
# 🔄 Processing: POST /api/v1/organizers/bigevents/events/sampleconf/items/1/bundles/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 42
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/items/(item)/bundles/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 43
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/items/(id)/bundles/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 44
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/(item)/addons/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 45
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/items/(item)/addons/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 46
#
# 🔄 Processing: POST /api/v1/organizers/bigevents/events/sampleconf/items/1/addons/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 47
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/items/(item)/addon/(id)/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 48
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/items/(id)/addons/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 49
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/item_meta_properties/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 50
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/item_meta_properties/(id)/
# ✅ Generated test inserted at row 51
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/item_meta_properties/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 52
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/item_meta_properties/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 53
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/item_meta_properties/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 54
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/
# ✅ Generated test inserted at row 55
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 56
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/teams/
# ✅ Generated test inserted at row 57
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/teams/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 58
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/teams/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 59
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/(team)/members/
# ✅ Generated test inserted at row 60
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/(team)/members/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 61
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/teams/(team)/members/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 62
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/(team)/invites/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 63
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/(team)/invites/(id)/
# ✅ Generated test inserted at row 64
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/teams/(team)/invites/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 65
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/teams/(team)/invites/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 66
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/(team)/tokens/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 67
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/teams/(team)/tokens/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 68
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/teams/(team)/tokens/
# ✅ Generated test inserted at row 69
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/teams/(team)/tokens/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 70
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/customers/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 71
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/customers/(identifier)/
# ✅ Generated test inserted at row 72
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/customers/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 73
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/customers/(identifier)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 74
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/customers/(identifier)/anonymize/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 75
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/discounts/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 76
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/discounts/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 77
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/discounts/
# ✅ Generated test inserted at row 78
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/discounts/(id)/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 79
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/discount/(id)/
# ✅ Generated test inserted at row 80
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/devices/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 81
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/devices/(device_id)/
# ✅ Generated test inserted at row 82
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/devices/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 83
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/devices/(device_id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 84
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/memberships/
# ✅ Generated test inserted at row 85
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/memberships/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 86
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/memberships/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 87
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/memberships/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 88
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/membershiptypes/
# ✅ Generated test inserted at row 89
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/membershiptypes/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 90
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/membershiptypes/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 91
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/membershiptypes/(id)/
# ✅ Generated test inserted at row 92
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/membershiptypes/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 93
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/saleschannels/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 94
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/saleschannels/(identifier)/
# ✅ Generated test inserted at row 95
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/saleschannels/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 96
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/saleschannels/(identifier)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 97
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/saleschannels/(identifier)/
# ✅ Generated test inserted at row 98
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/seatingplans/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 99
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/seatingplans/(id)/
# ✅ Generated test inserted at row 100
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/seatingplans/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 101
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/seatingplans/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 102
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/seatingplans/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 103
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/giftcards/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 104
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/giftcards/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 105
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/giftcards/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 106
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/giftcards/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 107
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/giftcards/(id)/transact/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 108
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/giftcards/(id)/transactions/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 109
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/sendmail_rules/
# ✅ Generated test inserted at row 110
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/sendmail_rules/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 111
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/sendmail_rules/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 112
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/sendmail_rules/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 113
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/sendmail_rules/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 114
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/webhooks/
# ✅ Generated test inserted at row 115
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/webhooks/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 116
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/webhooks/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 117
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/webhooks/(id)/
# ✅ Generated test inserted at row 118
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/webhook/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 119
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/reusablemedia/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 120
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/reusablemedia/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 121
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/reusablemedia/lookup/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 122
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/reusablemedia/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 123
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/reusablemedia/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 124
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/vouchers/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 125
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/vouchers/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 126
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/vouchers/
# ✅ Generated test inserted at row 127
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/vouchers/batch_create/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 128
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/vouchers/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 129
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/vouchers/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 130
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/waitinglistentries/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 131
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/waitinglistentries/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 132
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/waitinglistentries/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 133
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/waitinglistentries/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 134
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/waitinglistentries/(id)/send_voucher/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 135
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/waitinglistentries/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 136
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/checkinlists/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 137
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/checkinlists/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 138
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/checkinlists/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 139
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/checkinlists/(id)/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 140
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/checkinlists/(id)/status/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 141
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/checkinlists/(list)/positions/(id)/redeem/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 142
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/checkinlists/(list)/failed_checkins/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 143
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orders/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/orders/
# ✅ Generated test inserted at row 145
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orders/(code)/
# ✅ Generated test inserted at row 146
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/
# ✅ Generated test inserted at row 147
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/reactivate/
# ✅ Generated test inserted at row 148
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/approve/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 149
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/deny/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 150
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/orders/(code)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 151
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/create_invoice/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 152
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/regenerate_secrets/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 153
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orderpositions/(id)/regenerate_secrets/
# ✅ Generated test inserted at row 154
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/resend_link/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 155
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orderpositions/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orderpositions/(id)/
# ✅ Generated test inserted at row 157
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/orderpositions/(id)/
# ✅ Generated test inserted at row 158
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orderpositions/(id)/printlog/
# ✅ Generated test inserted at row 159
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orders/(code)/payments/
# ✅ Generated test inserted at row 160
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orders/(code)/payments/(local_id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 161
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/payments/(local_id)/confirm/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 162
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/payments/(local_id)/cancel/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 163
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/payments/(local_id)/refund/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 164
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/payments/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 165
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orders/(code)/refunds/
# ✅ Generated test inserted at row 166
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/orders/(code)/refunds/(local_id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 167
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/refunds/(local_id)/done/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 168
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/refunds/(local_id)/cancel/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 169
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/orders/(code)/refunds/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 170
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/revokedsecrets/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 171
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/blockedsecrets/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 172
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/invoices/
# Rate limit hit. Waiting before retry...
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 173
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/invoices/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 174
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/invoices/(number)/
# ✅ Generated test inserted at row 175
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/invoices/(number)/reissue/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 176
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/invoices/(number)/regenerate/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 177
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/questions/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 178
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/questions/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 179
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/questions/
# ✅ Generated test inserted at row 180
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/questions/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 181
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/questions/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 182
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/questions/(question)/options/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 183
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/questions/(question)/options/(id)/
# ✅ Generated test inserted at row 184
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/questions/(question)/options/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 185
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/questions/(question)/options/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 186
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/questions/(id)/options/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 187
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/quotas/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 188
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/quotas/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 189
#
# 🔄 Processing: POST /api/v1/organizers/(organizer)/events/(event)/quotas/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 190
#
# 🔄 Processing: PATCH /api/v1/organizers/(organizer)/events/(event)/quotas/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 191
#
# 🔄 Processing: DELETE /api/v1/organizers/(organizer)/events/(event)/quota/(id)/
# Rate limit hit. Waiting before retry...
# ✅ Generated test inserted at row 192
#
# 🔄 Processing: GET /api/v1/organizers/(organizer)/events/(event)/quotas/(id)/availability/
# ✅ Generated test inserted at row 193
#
# ✅ All generated tests have been saved in '/content/scenario2.xlsx'.

# %% [markdown]
# # **Evaluasi**

# %%
chrf_evaluator = evaluate.load("chrf")
bleu_evaluator = evaluate.load("bleu")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading builder script: 0.00B [00:00, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules: 0.00B [00:00, ?B/s]

# %%
def evaluate_code(filepath):
    codebleu_scores, bleu_scores = [], []
    chrf_scores = []

    print("===== START EVALUATION FROM EXCEL =====\n")

    # Load Excel file
    df = pd.read_excel(filepath)

    for i, row in df.iterrows():
        print(f"Data ke-{i}")

        reference_code = row.get("Reference Test")
        candidate_code = row.get("Generated Test")

        if pd.isna(reference_code) or pd.isna(candidate_code):
            print("⚠️ Skipping this example due to missing data.")
            continue

        try:
            if not str(reference_code).strip() or not str(candidate_code).strip():
                print("⚠️ Warning: reference_code or candidate_code is empty. Skipping evaluations.")
                codebleu_metric = {"codebleu": 0.0}
                bleu_metric = {"bleu": 0.0}
                chrf_metric = {"score": 0.0}
            else:
                codebleu_metric = calc_codebleu(
                    references=[[reference_code]],
                    predictions=[candidate_code],
                    lang="python",
                    weights=(0.25, 0.25, 0.25, 0.25),
                    tokenizer=None
                )
                bleu_metric = bleu_evaluator.compute(predictions=[candidate_code], references=[[reference_code]])
                chrf_metric = chrf_evaluator.compute(predictions=[candidate_code], references=[[reference_code]])

        except Exception as e:
            print(f"⚠️ Error in evaluation: {e}")
            continue

        bleu_score = bleu_metric.get('bleu', 0.0)
        codebleu_score = codebleu_metric.get('codebleu', 0.0)
        chrf_score = chrf_metric.get('score', 0.0)

        bleu_scores.append(bleu_score)
        chrf_scores.append(chrf_score)
        codebleu_scores.append(codebleu_score)

    def safe_average(scores):
        return sum(scores) / len(scores) if scores else 0.0

    return {
        "avg_codebleu": f"{safe_average(codebleu_scores)}",
        "avg_bleu": f"{safe_average(bleu_scores)}",
        "avg_chrf_scores": f"{safe_average(chrf_scores)}",
        "": "",
        "=============": "PERCENT ==================",
        "": "",
        "Avg CodeBLEU": f"{round(safe_average(codebleu_scores) * 100, 2)}%",
        "Avg BLEU": f"{round(safe_average(bleu_scores) * 100, 2)}%",
        "Avg chrF": f"{round(safe_average(chrf_scores), 2)}%",
    }

# %%
filepath = "/content/scenario2.xlsx"

result_evaluate = evaluate_code(filepath)
print("\n ------------ RESULT EVALUATE ---------------")
print(json.dumps(result_evaluate, indent=4))
# Out:
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# ===== START EVALUATION FROM EXCEL =====
#
# Data ke-0
# Data ke-1
# Data ke-2
# Data ke-3
# Data ke-4
# Data ke-5
# Data ke-6
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# Data ke-7
# Data ke-8
# Data ke-9
# Data ke-10
# Data ke-11
# Data ke-12
# Data ke-13
# Data ke-14
# Data ke-15
# Data ke-16
# Data ke-17
# Data ke-18
# Data ke-19
# Data ke-20
# Data ke-21
# Data ke-22
# Data ke-23
# Data ke-24
# Data ke-25
# Data ke-26
# Data ke-27
# Data ke-28
# Data ke-29
# Data ke-30
# Data ke-31
# Data ke-32
# Data ke-33
# Data ke-34
# Data ke-35
# Data ke-36
# Data ke-37
# Data ke-38
# Data ke-39
# Data ke-40
# Data ke-41
# Data ke-42
# Data ke-43
# Data ke-44
# Data ke-45
# Data ke-46
# Data ke-47
# Data ke-48
# Data ke-49
# Data ke-50
# Data ke-51
# Data ke-52
# Data ke-53
# Data ke-54
# Data ke-55
# Data ke-56
# Data ke-57
# Data ke-58
# Data ke-59
# Data ke-60
# Data ke-61
# Data ke-62
# Data ke-63
# Data ke-64
# Data ke-65
# Data ke-66
# Data ke-67
# Data ke-68
# Data ke-69
# Data ke-70
# Data ke-71
# Data ke-72
# Data ke-73
# Data ke-74
# Data ke-75
# Data ke-76
# Data ke-77
# Data ke-78
# Data ke-79
# Data ke-80
# Data ke-81
# Data ke-82
# Data ke-83
# Data ke-84
# Data ke-85
# Data ke-86
# Data ke-87
# Data ke-88
# Data ke-89
# Data ke-90
# Data ke-91
# Data ke-92
# Data ke-93
# Data ke-94
# Data ke-95
# Data ke-96
# Data ke-97
# Data ke-98
# Data ke-99
# Data ke-100
# Data ke-101
# Data ke-102
# Data ke-103
# Data ke-104
# Data ke-105
# Data ke-106
# Data ke-107
# Data ke-108
# Data ke-109
# Data ke-110
# Data ke-111
# Data ke-112
# Data ke-113
# Data ke-114
# Data ke-115
# Data ke-116
# Data ke-117
# Data ke-118
# Data ke-119
# Data ke-120
# Data ke-121
# Data ke-122
# Data ke-123
# Data ke-124
# Data ke-125
# Data ke-126
# Data ke-127
# Data ke-128
# Data ke-129
# Data ke-130
# Data ke-131
# Data ke-132
# Data ke-133
# Data ke-134
# Data ke-135
# Data ke-136
# Data ke-137
# Data ke-138
# Data ke-139
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# Data ke-140
# Data ke-141
# Data ke-142
# ⚠️ Skipping this example due to missing data.
# Data ke-143
# Data ke-144
# Data ke-145
# Data ke-146
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# Data ke-147
# Data ke-148
# Data ke-149
# Data ke-150
# Data ke-151
# Data ke-152
# Data ke-153
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# Data ke-154
# ⚠️ Skipping this example due to missing data.
# Data ke-155
# Data ke-156
# Data ke-157
# Data ke-158
# Data ke-159
# Data ke-160
# Data ke-161
# Data ke-162
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# WARNING:root:WARNING: There is no reference data-flows extracted from the whole corpus, and the data-flow match score degenerates to 0. Please consider ignoring this score.
# Data ke-163
# Data ke-164
# Data ke-165
# Data ke-166
# Data ke-167
# Data ke-168
# Data ke-169
# Data ke-170
# Data ke-171
# Data ke-172
# Data ke-173
# Data ke-174
# Data ke-175
# Data ke-176
# Data ke-177
# Data ke-178
# Data ke-179
# Data ke-180
# Data ke-181
# Data ke-182
# Data ke-183
# Data ke-184
# Data ke-185
# Data ke-186
# Data ke-187
# Data ke-188
# Data ke-189
# Data ke-190
# Data ke-191
#
#  ------------ RESULT EVALUATE ---------------
# {
#     "avg_codebleu": "0.2870132856856345",
#     "avg_bleu": "0.17299497324759983",
#     "avg_chrf_scores": "42.9567825173456",
#     "": "",
#     "=============": "PERCENT ==================",
#     "Avg CodeBLEU": "28.7%",
#     "Avg BLEU": "17.3%",
#     "Avg chrF": "42.96%"
# }

# %%
candidate_code = """
def test_organizer_list(token_client, organizer):
    response = token_client.get("/api/organizers")
    assert response.status_code == 200
    organizers = response.json()
    assert len(organizers) > 0
    for organizer_data in organizers:
        assert "id" in organizer_data
        assert "name" in organizer_data
        assert "description" in organizer_data
    # Test failure scenario: unauthorized access
    token_client2 = token_client._replace(headers={"Authorization": "Bearer invalid_token"})
    response2 = token_client2.get("/api/organizers")
    assert response2.status_code == 401
"""

reference_code = """
def test_organizer_list(token_client, organizer):
    resp = token_client.get('/api/v1/organizers/')
    assert resp.status_code == 200
    assert TEST_ORGANIZER_RES in resp.data['results']
"""

if not reference_code.strip() or not candidate_code.strip():
    print("Warning: reference_code or candidate_code is empty. Skipping evaluations.")
    codebleu = {"codebleu": 0.0}
    bleu_metric = {"bleu": 0.0}
    chrf_metric = {"score": 0.0}
else:
    codebleu = calc_codebleu(
        references=[[reference_code]],
        predictions=[candidate_code],
        lang="python",
        weights=(0.25, 0.25, 0.25, 0.25)
    )
    bleu_metric = bleu_evaluator.compute(predictions=[candidate_code], references=[[reference_code]])
    chrf_metric = chrf_evaluator.compute(predictions=[candidate_code], references=[[reference_code]])


def format_score(score, is_percentage_scale=False):
    if is_percentage_scale:
        return f"{score:.2f}%"
    return f"{score * 100:.2f}% ({score:.2f})"

print(f"--> BLEU\t: {format_score(bleu_metric.get('bleu', 0.0))}\n")
print(f"--> CodeBLEU\t: {format_score(codebleu.get('codebleu', 0.0))}\n")
print(f"--> chrF\t: {format_score(chrf_metric.get('score', 0.0), is_percentage_scale=True)}\n")
# Out:
# --> BLEU	: 19.50% (0.20)
#
# --> CodeBLEU	: 45.06% (0.45)
#
# --> chrF	: 47.68%
